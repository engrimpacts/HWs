# %% [markdown]
# # Homework 7
# ## Intro to working in the Python programming language.
#
# ### Some Resources
# * Codecademy tutorial: https://www.codecademy.com/learn/python
# * Another tutorial: http://www.learnpython.org/
# * Basic notebook features: https://github.com/ngs-docs/2016-mar-jupyter/blob/master/1-intro-script.md
# * Some more intro: http://goo.gl/Qdn9ZH
# * A more advanced intro with useful examples: http://goo.gl/Ade3XE
# * To create a Jupyter notebook: https://notebooks.azure.com You should be able to sign in with your Stout credentials.
#
# **Note: I expect that you will also need to do some internet searching to figure out how to do things. This is part of the process.**
#
# ## Part a
# * Read in the data_2.txt file from D2L. Note that files can be uploaded to Azure as datasets and then read into the notebook.
# * Recall that the first data point in the file is the step associated with each additional data point. It needs to be deleted from your data before going further.
# * In order to plot the data, you will need an array for your X-axis. Create one in agreement with the timestep.
#
# ## Part b
# * Plot the data from the file vs the X-axis array your created in Part a.
# * Remember to put "%matplotlib inline" (without the quotes) at the beginning so your plots display inline.
#
# ## Part c
# * You may notice that the data looks like it repeats.
# * Trim this down to only a few repeated events and replot the data.
# * Add axis labels and a chart title. (What is this data representing?)
#
# ## Finishing Up / Submission
# To turn in this homework, click "File" at the top and then "Download as" > "PDF via LaTeX (.pdf)". Upload the resulting PDF file to the dropbox on D2L.
